# %%
import pandas as pd
import os

# print("Pandas version:", pd.__version__)
# print("Pandas is ready!")      
print(os.getcwd())
#print(os.listdir())
# Out:
# C:\Users\SBHARAN\AppData\Local\Programs\Microsoft VS Code

# %%
import pandas as pd

# Create a DataFrame from a list of dictionaries
# Think of this as your SOURCE data coming into a pipeline
data = [
    {"transaction_id": 12345, "amount": 100,   "currency": "USD", "status": "Active"},
    {"transaction_id": 12346, "amount": 60000, "currency": "INR", "status": "Active"},
    {"transaction_id": 12347, "amount": 25000, "currency": "CAN", "status": "Inactive"},
    {"transaction_id": 12348, "amount": 500,   "currency": "USD", "status": "Active"},
    {"transaction_id": 12349, "amount": 15000, "currency": "GBP", "status": "Inactive"},
]

df = pd.DataFrame(data)

# Display the table — like previewing source data in Informatica
# print("shape:",df.shape)
# print("columns",df.columns)
# print("columns",df.columns.tolist())
# print(df.dtypes)
# print(df.describe())
# print(df.head(3))
# print(df.tail(2))
df.to_csv(r"C:\Users\SBHARAN\pyspark_jobs\output\transactions.csv", index=False)
df.to_pdf(r"C:\Users\SBHARAN\pyspark_jobs\output\transactions.pdf", index=False)
#print("Data)Frame created and saved to transactions.csv")
#print(df.to_pdf(index=False))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27016\3251378455.py in ?()
#      20 # print(df.describe())
#      21 # print(df.head(3))
#      22 # print(df.tail(2))
#      23 df.to_csv(r"C:\Users\SBHARAN\pyspark_jobs\output\transactions.csv", index=False)
# ---> 24 df.to_pdf(r"C:\Users\SBHARAN\pyspark_jobs\output\transactions.pdf", index=False)
#      25 #print("Data)Frame created and saved to transactions.csv")
#      26 #print(df.to_pdf(index=False))
#
# c:\Users\SBHARAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_pdf'

# %%
import pandas as pd
from tabulate import tabulate
df=pd.read_csv(r"C:\Users\SBHARAN\pyspark_jobs\output\transactions.csv",delimiter=',')
#print(df.to_csv(index=False))
tabulare_df = tabulate(df, headers='keys', tablefmt='psql', showindex=False)
print(tabulare_df)
# Out:
# +------------------+----------+------------+----------+
# |   transaction_id |   amount | currency   | status   |
# |------------------+----------+------------+----------|
# |            12345 |      100 | USD        | Active   |
# |            12346 |    60000 | INR        | Active   |
# |            12347 |    25000 | CAN        | Inactive |
# |            12348 |      500 | USD        | Active   |
# |            12349 |    15000 | GBP        | Inactive |
# +------------------+----------+------------+----------+
