# %%
def Santosh(balance):
  if balance > 10000:
    return "Balance is good"
  elif balance > 7000:
    return "Balance is average"
  elif balance > 5000 and balance <=7000:
    return "Balance is below average"
  else:
    return "Balance is very low"
  
print(Santosh(7000))
# Out:
# Balance is below average

# %%
customer_name = "John Smith"
account_balance = 120000.50
account_id =  12345
is_active = True

print(f"customer_name is " ,customer_name)
print(f"customer Account Balance is " , account_balance)
print(f"customer Account Id is " , account_id)
print(f"Cistomer is Active",is_active)
# Out:
# customer_name is  John Smith
# customer Account Balance is  120000.5
# customer Account Id is  12345
# Cistomer is Active True

# %%
#list
account_id=[100234, 100235, 100236, 100237]
print(account_id[0])
print(account_id[1])
print(account_id[2])
print(account_id[3])

#Dictionary
Customer = {
    "name": "John Smith",
    "balance": 120000.50,
    "account_id": 12345,
    "is_active": True
}
print( Customer["name"])
print(Customer ["balance"])
# Out:
# 100234
# 100235
# 100236
# 100237
# John Smith
# 120000.5

# %%
balance = 700.50
if (balance > 10000):
    print("balance is higher")
elif (balance > 7000) :
    print("balance is average")
elif (balance > 5000) :
    print("balance is low")
else :
    print("balance is very low")
# Out:
# balance is very low

# %%
account_ids=[100234,100235,100236,100237]
for i in account_ids:
    print(f"processing Account ID's" , i)
# Out:
# processing Account ID's 100234
# processing Account ID's 100235
# processing Account ID's 100236
# processing Account ID's 100237

# %%
###Function
def Santosh(balance):
  if balance > 10000:
    return "Balance is good"
  elif balance > 7000:
    return "Balance is average"
  elif balance > 5000 and balance <7200:
    return "Balance is below average"
  else:
    return "Balance is very low"


print(Santosh(balance=12000))
# Out:
# Balance is good

# %%
Bank_Transaction= [{
    "transaction_id" :  12345,
    "amount" : 100,
   "currency" : "USD",
   "Status": "Active"
    },     {
    "transaction_id" :  12346,
    "amount" : 200,
   "currency" : "INR",
   "Status": "Active"
    }, {
    "transaction_id" :  12347,
    "amount" : 300,
   "currency" : "CAN",
   "Status": "Active"
    }]

Bank_Transaction_History= {"transaction_id" :  12345,
    "amount" : 100,
   "currency" : "USD",
   "Status": "Active"
    }

print(Bank_Transaction_History ["transaction_id"])
print(Bank_Transaction_History ["amount"])
print(Bank_Transaction_History ["currency"])
print(Bank_Transaction_History ["Status"])
for i in Bank_Transaction:
  print(i)
# Out:
# 12345
# 100
# USD
# Active
# {'transaction_id': 12345, 'amount': 100, 'currency': 'USD', 'Status': 'Active'}
# {'transaction_id': 12346, 'amount': 200, 'currency': 'INR', 'Status': 'Active'}
# {'transaction_id': 12347, 'amount': 300, 'currency': 'CAN', 'Status': 'Active'}

# %%
TransactionAmounts=[25000,35000,45000,5000,15000]
from IPython.core.prefilter import AutoMagicChecker
def flag_transaction(amount):
 if amount >50000:
   return "Suspicious"
 elif amount > 10000:
   return "Review"
 elif amount <= 10000:
   return "Clear"

for i in TransactionAmounts:
  print("the amoint is ",i,"for" ,flag_transaction(i))
# Out:
# the amoint is  25000 for Review
# the amoint is  35000 for Review
# the amoint is  45000 for Review
# the amoint is  5000 for Clear
# the amoint is  15000 for Review

# %%
print ("Hello! I am learning python for Palantir Foundry)")
# Out:
# Hello! I am learning python for Palantir Foundry)
